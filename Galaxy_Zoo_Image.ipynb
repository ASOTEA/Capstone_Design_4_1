# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
zoo_F = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/gz2_filename_mapping.csv')

zoo_H = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/gz2_hart16.csv')


zoo_M_P = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/zoo2MainPhotoz.csv')
zoo_M_S = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/zoo2MainSpecz.csv')

zoo_S_1 = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/zoo2Stripe82Coadd1.csv')
zoo_S_2 = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/zoo2Stripe82Coadd2.csv')
zoo_S_N = main = pd.read_csv('/content/drive/MyDrive/galaxy_zoo/zoo2Stripe82Normal.csv')

# %%
# zoo_F['sample'].value_counts()   # O : 245609 , e : 28174 ,  stripe : 21522, stripe82_coadd_1 : 30346  stripe82_coadd_2 : 30339

# zoo_H['sample'].value_counts()   # O : 209294 , e : 21844, stripe : 8557

# zoo_M_S['sample'].value_counts() # O : 211922 , e : 23041, stripe : 8537
# zoo_M_P['sample'].value_counts() # O : 33619 , e : 5116, stripe : 3727

# zoo_S_N['sample'].value_counts() # stripe82         : 17787
# zoo_S_1['sample'].value_counts() # stripe82_coadd_1 : 19765
# zoo_S_2['sample'].value_counts() # stripe82_coadd_2 : 19761

# %%
zoo_F['is_in_zoo_H'] = zoo_F['objid'].isin(zoo_H['dr7objid'])

zoo_F['is_in_zoo_M_S'] = zoo_F['objid'].isin(zoo_M_S['dr7objid'])
zoo_F['is_in_zoo_M_P'] = zoo_F['objid'].isin(zoo_M_P['dr7objid'])

zoo_F['is_in_zoo_S_N'] = zoo_F['objid'].isin(zoo_S_N['dr7objid'])
zoo_F['is_in_zoo_S_1'] = zoo_F['objid'].isin(zoo_S_1['dr7objid'])
zoo_F['is_in_zoo_S_2'] = zoo_F['objid'].isin(zoo_S_2['dr7objid'])

# %%
zoo_H_true = zoo_F.index[zoo_F['is_in_zoo_H']].tolist()

zoo_M_S_true = zoo_F.index[zoo_F['is_in_zoo_M_S']].tolist()
zoo_M_P_true = zoo_F.index[zoo_F['is_in_zoo_M_P']].tolist()

zoo_S_N_true = zoo_F.index[zoo_F['is_in_zoo_S_N']].tolist()
zoo_S_1_true = zoo_F.index[zoo_F['is_in_zoo_S_1']].tolist()
zoo_S_2_true = zoo_F.index[zoo_F['is_in_zoo_S_2']].tolist()

# %%
zoo_H.columns[28:50]
# Out:
# Index(['t02_edgeon_a04_yes_weight', 't02_edgeon_a04_yes_fraction',
#        't02_edgeon_a04_yes_weighted_fraction', 't02_edgeon_a04_yes_debiased',
#        't02_edgeon_a04_yes_flag', 't02_edgeon_a05_no_count',
#        't02_edgeon_a05_no_weight', 't02_edgeon_a05_no_fraction',
#        't02_edgeon_a05_no_weighted_fraction', 't02_edgeon_a05_no_debiased',
#        't02_edgeon_a05_no_flag', 't03_bar_a06_bar_count',
#        't03_bar_a06_bar_weight', 't03_bar_a06_bar_fraction',
#        't03_bar_a06_bar_weighted_fraction', 't03_bar_a06_bar_debiased',
#        't03_bar_a06_bar_flag', 't03_bar_a07_no_bar_count',
#        't03_bar_a07_no_bar_weight', 't03_bar_a07_no_bar_fraction',
#        't03_bar_a07_no_bar_weighted_fraction', 't03_bar_a07_no_bar_debiased'],
#       dtype='object')

# %%
# !unzip -qq '/content/drive/MyDrive/galaxy_zoo/images_gz2.zip'

# %%
 dir = '/content/images/'

 cnt = 0  # 짧게 확인
 for i in true:
    filename = dir + str(i)+'.jpg'
    print(filename)
    cnt += 1
    if cnt == 10 :
        break
# Out:
# /content/images/2.jpg
# /content/images/3.jpg
# /content/images/4.jpg
# /content/images/5.jpg
# /content/images/6.jpg
# /content/images/7.jpg
# /content/images/8.jpg
# /content/images/10.jpg
# /content/images/11.jpg
# /content/images/12.jpg

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
im = cv2.imread(filename)
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=424x424>
